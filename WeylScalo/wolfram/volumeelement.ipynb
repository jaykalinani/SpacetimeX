# %% [markdown]
# # Volume Element

# %%
Needs["xAct`xCoba`", FileNameJoin[{Environment["GENERATO"], "src/Generato.wl"}]]
# Out:
# ------------------------------------------------------------
# Package xAct`xPerm`  version 1.2.3, {2015, 8, 23}
# CopyRight (C) 2003-2020, Jose M. Martin-Garcia, under the General Public\
#
# >   License.
# Connecting to external mac executable...
# Connection established.
# ------------------------------------------------------------
# Package xAct`xTensor`  version 1.2.0, {2021, 10, 17}
# CopyRight (C) 2002-2021, Jose M. Martin-Garcia, under the General Public\
#
# >   License.
# ------------------------------------------------------------
# These packages come with ABSOLUTELY NO WARRANTY; for details type\
#
# >   Disclaimer[]. This is free software, and you are welcome to redistribute\
#
# >   it under certain conditions. See the General Public License for details.
# ------------------------------------------------------------
# ------------------------------------------------------------
# Package xAct`xCoba`  version 0.8.6, {2021, 2, 28}
# ...

# %%
DefManifold[M3, 3, IndexRange[a, z]];

# %%
DefChart[cart, M3, {1, 2, 3}, {X[], Y[], Z[]}, ChartColor -> Blue];

# %%
DefMetric[1, gam[-i, -j], cd, SymbolOfCovD -> {"|", "D"}, PrintAs -> "\[Gamma]"];

# %%
MetricInBasis[gam, -cart,
    {
        {gam11, gam12, gam13},
        {gam12, gam22, gam23},
        {gam13, gam23, gam33}
    }];

# %%
<< "wl/WeylScal_vars.wl";

# %%
<< "wl/WeylScal_rhs.wl";

# %% [markdown]
# #### Examples

# %%
TensorValues[gam] // Rasterize
# Out:
# -Image-

# %%
BasisArray[cart][a] // Rasterize
# Out:
# -Image-

# %%
BasisArray[cart][-a] // Rasterize
# Out:
# -Image-

# %%
epsilongam[j, k, l] /. epsilonToetaUp[gam, cart] // Rasterize
# Out:
# -Image-

# %%
epsilongam[-j, -k, -l] /. epsilonToetaDown[gam, cart] // Rasterize
# Out:
# -Image-

# %%
epsilongam[{1, -cart}, {2, -cart}, {3, -cart}] /. epsilonToetaDown[gam, cart]
# Out:
# Sqrt[Detgamcart[]]

# %%
(epsilongam[{1, cart}, {2, cart}, {3, cart}] /. epsilonToetaUp[gam, cart] // ToValues) /. Detgamcart[] -> detgam
# Out:
#      1
# ------------
# Sqrt[detgam]

# %% [markdown]
# ## Check Expression

# %%
Bpart$RHS[{1, -cart}, {2, -cart}] // DummyToBasis[cart] // TraceBasisDummy // ToValues
# Out:
# DexK223 gam11 sqrtdetinvgam - DexK322 gam11 sqrtdetinvgam -
#
# >   DexK123 gam12 sqrtdetinvgam + DexK312 gam12 sqrtdetinvgam +
#
# >   DexK122 gam13 sqrtdetinvgam - DexK212 gam13 sqrtdetinvgam

# %%
(invgam[{1, cart}, l] epsilongam[-l, -j, -k] uvec[j] vvec[k] // DummyToBasis[cart] // TraceBasisDummy // ToValues) /. epsilonToetaDown[gam, cart] /. {Sqrt[Detgamcart[]] -> sqrtdetgam[]}
# Out:
# -(invgam13 uvec2 vvec1 sqrtdetgam[]) + invgam12 uvec3 vvec1 sqrtdetgam[] +
#
# >   invgam13 uvec1 vvec2 sqrtdetgam[] - invgam11 uvec3 vvec2 sqrtdetgam[] -
#
# >   invgam12 uvec1 vvec3 sqrtdetgam[] + invgam11 uvec2 vvec3 sqrtdetgam[]
